# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("mock_data.tsv", sep="\t", header=4)

# %%
final_df = df[["#clade_name", "NCBI_tax_id", "relative_abundance", "#clade_name"]]

# %%
final_df = final_df.rename(columns={'#clade_name': 'clade_name'})

# %%
final_df.columns = ["clade_name", "NCBI_tax_id", "relative_abundance", "OTU"]

# %%
final_df
# Out:
#                                             clade_name  \
# 0                                          k__Bacteria
# 1                                           k__Archaea
# 2                         k__Bacteria|p__Bacteroidetes
# 3                            k__Bacteria|p__Firmicutes
# 4                        k__Bacteria|p__Proteobacteria
# ..                                                 ...
# 853  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactob...
# 854  k__Bacteria|p__Actinobacteria|c__Actinomycetia...
# 855  k__Bacteria|p__Firmicutes|c__CFGB2915|o__OFGB2...
# 856  k__Bacteria|p__Firmicutes|c__CFGB2844|o__OFGB2...
# 857  k__Bacteria|p__Actinobacteria|c__Actinomycetia...
#
#                               NCBI_tax_id  relative_abundance  \
# 0                                       2            99.99647
# 1                                    2157             0.00353
# 2                                   2|976            55.80959
# ...
